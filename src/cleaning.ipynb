# %% [markdown]
# # Data Exploration of Environmental Data

# %% [markdown]
# #### Loading the Data

# %%
import pandas as pd

# %%
data = pd.read_csv("/Users/keonnartey/Downloads/data.csv", encoding="latin1")
len(data)
# Out:
# /var/folders/qs/rjygft750zb0p7_q7l9lhbw80000gn/T/ipykernel_33119/1969181001.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("/Users/keonnartey/Downloads/data.csv",encoding='latin1')

# %%
data.columns
# Out:
# Index(['stn_code', 'sampling_date', 'state', 'location', 'agency', 'type',
#        'so2', 'no2', 'rspm', 'spm', 'location_monitoring_station', 'pm2_5',
#        'date'],
#       dtype='object')

# %%
data.pm2_5.isnull()
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 435737    True
# 435738    True
# 435739    True
# 435740    True
# 435741    True
# Name: pm2_5, Length: 435742, dtype: bool

# %%
data.state.nunique()
# Out:
# 37

# %%
data.state.value_counts()
# Out:
# state
# Maharashtra                    60384
# Uttar Pradesh                  42816
# Andhra Pradesh                 26368
# Punjab                         25634
# Rajasthan                      25589
# Kerala                         24728
# Himachal Pradesh               22896
# West Bengal                    22463
# Gujarat                        21279
# Tamil Nadu                     20597
# Madhya Pradesh                 19920
# Assam                          19361
# Odisha                         19279
# Karnataka                      17119
# Delhi                           8551
# Chandigarh                      8520
# Chhattisgarh                    7831
# Goa                             6206
# Jharkhand                       5968
# Mizoram                         5338
# Telangana                       3978
# Meghalaya                       3853
# Puducherry                      3785
# Haryana                         3420
# Nagaland                        2463
# ...

# %%
data.location.value_counts()
# Out:
# location
# Guwahati      9984
# Hyderabad     9667
# Delhi         8551
# Chandigarh    8520
# Jaipur        7850
#               ...
# VAPI            24
# SANAND          23
# Khajuraho       16
# Gangtok          1
# Dharuhera        1
# Name: count, Length: 304, dtype: int64

# %%
data.type.nunique()
# Out:
# 10

# %%
data.type.value_counts()
# Out:
# type
# Residential, Rural and other Areas    179014
# Industrial Area                        96091
# Residential and others                 86791
# Industrial Areas                       51747
# Sensitive Area                          8980
# Sensitive Areas                         5536
# RIRUO                                   1304
# Sensitive                                495
# Industrial                               233
# Residential                              158
# Name: count, dtype: int64

# %%
data["date"] = pd.to_datetime(data.date)
data
# Out:
#        stn_code       sampling_date                        state   location  \
# 0         150.0  February - M021990               Andhra Pradesh  Hyderabad
# 1         151.0  February - M021990               Andhra Pradesh  Hyderabad
# 2         152.0  February - M021990               Andhra Pradesh  Hyderabad
# 3         150.0     March - M031990               Andhra Pradesh  Hyderabad
# 4         151.0     March - M031990               Andhra Pradesh  Hyderabad
# ...         ...                 ...                          ...        ...
# 435737     SAMP            24-12-15                  West Bengal   ULUBERIA
# 435738     SAMP            29-12-15                  West Bengal   ULUBERIA
# 435739      NaN                 NaN  andaman-and-nicobar-islands        NaN
# 435740      NaN                 NaN                  Lakshadweep        NaN
# 435741      NaN                 NaN                      Tripura        NaN
#
#                                            agency  \
# ...

# %%
data[data.date.dt.year > 2005]
# Out:
#        stn_code sampling_date           state   location  \
# 2768        NaN      1/3/2006  Andhra Pradesh  Hyderabad
# 2769        NaN      1/5/2006  Andhra Pradesh  Hyderabad
# 2770        NaN      1/8/2006  Andhra Pradesh  Hyderabad
# 2771        NaN     2/10/2006  Andhra Pradesh  Hyderabad
# 2772        NaN     14/2/2006  Andhra Pradesh  Hyderabad
# ...         ...           ...             ...        ...
# 435734     SAMP      15-12-15     West Bengal   ULUBERIA
# 435735     SAMP      18-12-15     West Bengal   ULUBERIA
# 435736     SAMP      21-12-15     West Bengal   ULUBERIA
# 435737     SAMP      24-12-15     West Bengal   ULUBERIA
# 435738     SAMP      29-12-15     West Bengal   ULUBERIA
#
#                                            agency              type   so2  \
# 2768                                          NaN  Industrial Areas   5.0
# 2769                                          NaN  Industrial Areas   5.1
# ...

# %%
data.isnull().sum()
# Out:
# stn_code                       144077
# sampling_date                       3
# state                               0
# location                            3
# agency                         149481
# type                             5393
# so2                             34646
# no2                             16233
# rspm                            40222
# spm                            237387
# location_monitoring_station     27491
# pm2_5                          426428
# date                                7
# dtype: int64

# %%
data.so2.mean()
# Out:
# 10.829414322672587

# %%
data.no2.mean()
# Out:
# 25.80962289781126
