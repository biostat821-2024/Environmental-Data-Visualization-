# %% [markdown]
# This notebook provides an end-to-end example of our Air Quality visualization library.

# %%
from cleaning_data import Environment
from Environment_viz import Visualization
from bio_viz import SO2PieChart
import pandas as pd

# %%
env = Environment("../data/data.csv")

# %%
df = env.df

# %% [markdown]
# ### Some basic analysis functions

# %%
env.average_nitrogen_oxide()
# Out:
# 25.80962289781126

# %%
env.average_sulphur_dioxide()
# Out:
# 10.829414322672587

# %%
env.state_max_so2()
# Out:
# state
# Andhra Pradesh                 228.000
# Arunachal Pradesh               13.000
# Assam                           56.000
# Bihar                          216.600
# Chandigarh                      55.500
# Chhattisgarh                    29.300
# Dadra & Nagar Haveli            23.900
# Daman & Diu                     34.300
# Delhi                          127.400
# Goa                            108.600
# Gujarat                        219.100
# Haryana                         48.300
# Himachal Pradesh                81.000
# Jammu & Kashmir                 35.000
# Jharkhand                      221.000
# Karnataka                      230.000
# Kerala                         126.900
# Lakshadweep                        NaN
# Madhya Pradesh                 199.800
# Maharashtra                    597.000
# Manipur                          5.900
# Meghalaya                      178.000
# Mizoram                          8.000
# Nagaland                         5.800
# ...

# %% [markdown]
# ### Visualization library

# %%
col_map = {
    "state": "state",
    "location": "location",
    "type": "type",
    "so2": "so2",
    "no2": "no2",
    "rspm": "rspm",
    "spm": "spm",
    "pm2_5": "pm2_5",
    "date": "date",
}
viz = Visualization(env, col_map)
viz.heatmap_pollutant_by_state_and_year("so2")
# Out:
# /Users/anastasiia/anaconda3/lib/python3.11/site-packages/seaborn/matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)

# %%
viz.heatmap_pollutant_by_state_and_year("no2")
# Out:
# /Users/anastasiia/anaconda3/lib/python3.11/site-packages/seaborn/matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)

# %% [markdown]
# # Pie Chart

# %%
# # Get the data using state_max_so2 method
state_max_so2_data = env.state_max_so2()

# # Create DataFrame from the output of state_max_so2
state_max_so2_df = pd.DataFrame(state_max_so2_data).reset_index()

# %%
state_max_so2_data
# Out:
# state
# Andhra Pradesh                 228.000
# Arunachal Pradesh               13.000
# Assam                           56.000
# Bihar                          216.600
# Chandigarh                      55.500
# Chhattisgarh                    29.300
# Dadra & Nagar Haveli            23.900
# Daman & Diu                     34.300
# Delhi                          127.400
# Goa                            108.600
# Gujarat                        219.100
# Haryana                         48.300
# Himachal Pradesh                81.000
# Jammu & Kashmir                 35.000
# Jharkhand                      221.000
# Karnataka                      230.000
# Kerala                         126.900
# Lakshadweep                        NaN
# Madhya Pradesh                 199.800
# Maharashtra                    597.000
# Manipur                          5.900
# Meghalaya                      178.000
# Mizoram                          8.000
# Nagaland                         5.800
# ...

# %%
# Plot chart using the DataFrame
so2_chart = SO2PieChart(state_max_so2_df)
so2_chart.process_data()
so2_chart.plot_chart()
